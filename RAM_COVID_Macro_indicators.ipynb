# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.pylabtools import figsize
figsize(20, 5)
from fredapi import Fred
import json
import seaborn as sns

# importing the requests library 
import requests

# %% [markdown]
# FRED (Federal Reserve St. Louis)

# %%
fred = Fred(api_key='98446267701683b76eae969888c5dd8a')

# %%
df = {}
#df['Indonesia'] = fred.get_series('RBIDBIS', observation_start='2019-01-01')
#df['Euro'] = fred.get_series('DEXUSEU', observation_start='2019-01-01')
df['Yuan'] = fred.get_series('DEXCHUS', observation_start='2019-01-01')
#df['India'] = fred.get_series('DEXINUS', observation_start='2019-01-01')
#df['Sri Lanka'] = fred.get_series('DEXSLUS', observation_start='2019-01-01')
df = pd.DataFrame(df)
df.plot()

# %% [markdown]
# Economic imports

# %%
df = {}
#df['Bangladesh'] = fred.get_series('IMP5380', observation_start='2019-01-01')
df['Laos'] = fred.get_series('IMP5530', observation_start='2018-01-01')
df = pd.DataFrame(df)
df.plot()

# %% [markdown]
# COVID cases

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'

df = pd.read_csv(url,index_col=0,parse_dates=True)

# %%
df.reset_index(drop=True, inplace=True)
df_clean = df.drop(['Lat', 'Long'], axis=1)
df_transposed = df_clean.T
df_transposed.columns = df_transposed.iloc[0]
df_transposed = df_transposed.drop(index='Country/Region')

# %%
df_transposed.tail()
# Out:
# Country/Region Afghanistan Albania Algeria Andorra Angola Antigua and Barbuda  \
# 3/18/20                 22      59      74      39      0                   1
# 3/19/20                 22      64      87      53      0                   1
# 3/20/20                 24      70      90      75      1                   1
# 3/21/20                 24      76     139      88      2                   1
# 3/22/20                 40      89     201     113      2                   1
#
# Country/Region Argentina Armenia Australia Australia  ... Venezuela Vietnam  \
# 3/18/20               79      84         3       267  ...        36      75
# 3/19/20               97     115         4       307  ...        42      85
# 3/20/20              128     136         6       353  ...        42      91
# 3/21/20              158     160         9       436  ...        70      94
# 3/22/20              266     194        19       669  ...        70     113
#
# ...

# %%
df_cases = {}
df_cases['Thailand'] = df_transposed['Thailand']
df_cases['Indonesia'] = df_transposed['Indonesia']
df_cases['Bangladesh'] = df_transposed['Bangladesh']
df_cases['Afghanistan'] = df_transposed['Afghanistan']
df_cases['Cambodia'] = df_transposed['Cambodia']
df_cases['Pakistan'] = df_transposed['Pakistan']
df_cases['India'] = df_transposed['India']
#df_cases['Myanmar'] = df_transposed['Myanmar']
df_cases['Sri Lanka'] = df_transposed['Sri Lanka']

df_cases_RBB = pd.DataFrame(df_cases)
df_cases_RBB.plot(logy=True)

# %% [markdown]
# IMF Data API

# %%
url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/Dataflow/'
